# %% [markdown]
# # First, import necessary packages

# %%
import librosa
from librosa import display
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio
import scipy

# %%
fn = "low.wav"

# %%
wave, sample_rate = librosa.load(fn)
print(type(wave), type(sample_rate))
print(sample_rate)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# 22050

# %%
Audio(fn)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Duration of sound
duration_of_sound = len(wave)/sample_rate
duration_of_sound
# Out:
# 3.2759637188208615

# %%
plt.figure()
librosa.display.waveplot(y = wave, sr = sample_rate)

# %%
yf = scipy.fft.fft(wave)
print(len(wave))
print(sample_rate)
T = 1.0/sample_rate
xf = np.linspace(0, duration_of_sound/2)
# Out:
# 72235
# 22050

# %%
plt.plot(np.abs(yf[:len(yf)//2]))

# %%
# Out:
# /home/victor/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
len(np.linspace(0,1/31, 10))
# Out:
# 10

# %%
len(wave)//2
# Out:
# 36117

# %%
2/sample_rate
# Out:
# 9.070294784580499e-05
